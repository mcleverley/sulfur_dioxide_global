# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#data-source" data-toc-modified-id="data-source-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>data source</a></span></li></ul></div>

# %%
from arcgis.gis import GIS
trailheads_id = '883cedb8c9fe4524b64d47666ed234a7'
gis = GIS()
trailheads_item = gis.content.get(trailheads_id)
trailheads_item
m = gis.map()
m.add_layer(trailheads_item)

# %%
type(m)
# Out:
# arcgis.widgets._mapview.MapView

# %%
m
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-6f42e827-54a7-4e68-b75b-79d26ab17bd8"><img src=""></img></div>

# %%
m.center = [34.09042, -118.71511]           # `[latitude, longitude]`
m.zoom = 11

# %%
import pandas as pd
df = pd.read_csv('../data/12-11-2020.csv')
df.describe()
# Out:
#              Lat       Long_     Confirmed        Deaths     Recovered  \
# count  56.000000   56.000000  5.800000e+01     58.000000  4.800000e+01
# mean   36.840089  -85.206614  2.731515e+05   5093.965517  1.278190e+05
# std    10.887035   49.754449  3.168640e+05   6894.742996  1.903550e+05
# min   -14.271000 -170.132000  0.000000e+00      0.000000  2.900000e+01
# 25%    34.594600 -101.165775  6.072825e+04    839.750000  1.425975e+04
# 50%    39.061850  -87.944200  1.919360e+05   2677.000000  5.591350e+04
# 75%    42.361650  -76.970625  3.854340e+05   5654.750000  1.842172e+05
# max    61.370700  145.673900  1.516215e+06  35357.000000  1.157334e+06
#
#              Active          FIPS  Incident_Rate  Total_Test_Results  \
# count  5.800000e+01     58.000000      56.000000        5.600000e+01
# mean   1.622763e+05   3288.086207    4854.518937        3.810423e+06
# std    2.702915e+05  17408.350591    2243.695109        4.994566e+06
# ...

# %% [markdown]
# ### data source
# https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv

# %%
df.head(10)
# Out:
#      Province_State Country_Region          Last_Update      Lat     Long_  \
# 0           Alabama             US  2020-12-12 05:30:32  32.3182  -86.9023
# 1            Alaska             US  2020-12-12 05:30:32  61.3707 -152.4044
# 2    American Samoa             US  2020-12-12 05:30:32 -14.2710 -170.1320
# 3           Arizona             US  2020-12-12 05:30:32  33.7298 -111.4312
# 4          Arkansas             US  2020-12-12 05:30:32  34.9697  -92.3731
# 5        California             US  2020-12-12 05:30:32  36.1162 -119.6816
# 6          Colorado             US  2020-12-12 05:30:32  39.0598 -105.3111
# 7       Connecticut             US  2020-12-12 05:30:32  41.5978  -72.7554
# 8          Delaware             US  2020-12-12 05:30:32  39.3185  -75.5071
# 9  Diamond Princess             US  2020-12-12 05:30:32      NaN       NaN
#
#    Confirmed  Deaths  Recovered     Active     FIPS  Incident_Rate  \
# 0     288775    4086   174805.0   109884.0      1.0    5889.539146
# ...

# %% [markdown]
# so the unique identifier is province/state, and magnitude is handled by each column
# i guess a dataset of "lat/long of each person" would be much harder to record. which locations are you going to denote, their exact address?

# %%
len(df)
# Out:
# 58

# %%
df.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'Total_Test_Results', 'People_Hospitalized', 'Case_Fatality_Ratio',
#        'UID', 'ISO3', 'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Province_State          58
# Country_Region           1
# Last_Update              1
# Lat                     56
# Long_                   56
# Confirmed               58
# Deaths                  57
# Recovered               48
# Active                  58
# FIPS                    58
# Incident_Rate           56
# Total_Test_Results      56
# People_Hospitalized      0
# Case_Fatality_Ratio     57
# UID                     58
# ISO3                     6
# Testing_Rate            56
# Hospitalization_Rate     0
# dtype: int64
